# %%
import matplotlib.pyplot as plt      #시각화를 위한 설치
import matplotlib.font_manager as fm    # 한글 폰트
import matplotlib                   #시각화를 위한 설치
import os, warnings  
import pandas as pd                #구조 변경 및 결합을 하기 위한 설치        
import plotly.express as px        #시각화를 위한 설치

warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)         #모든 행을 다 보여주라는 명령
pd.set_option('display.max_columns', None)      #모든 열을 다 보여주라는 명령
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %%
hospital= pd.read_csv('a.csv')

# %%
train=hospital[(hospital['ACCOUNTDATE']>='2018-01-02')&(hospital['ACCOUNTDATE']<='2018-03-30')]
test=hospital[(hospital['ACCOUNTDATE']>='2018-04-02')&(hospital['ACCOUNTDATE']<='2018-04-30')]
train['ACCOUNTDATE']=train['ACCOUNTDATE'].astype('str')
train['ACCOUNTDATE']=pd.to_datetime(train['ACCOUNTDATE'])
train.index=train['ACCOUNTDATE']
train.set_index('ACCOUNTDATE',inplace=True)

# %%
def getresult_auto_arima():
     # todo
#     if name == "main":
#         hospital = pd.read_csv('a.csv')
#     else:
#         df = pd.DataFrame(request_json)
    train=hospital[(hospital['ACCOUNTDATE']>='2018-01-02')&(hospital['ACCOUNTDATE']<='2018-03-30')]
    train['ACCOUNTDATE']=train['ACCOUNTDATE'].astype('str')
    train['ACCOUNTDATE']=pd.to_datetime(train['ACCOUNTDATE'])
    train.index=train['ACCOUNTDATE']
    train.set_index('ACCOUNTDATE',inplace=True)

    order_list = []
    order_list1 = []
    order_list2 = []
    aic_list = []
    bic_list = []

    order = [3, 3, 3]
    for p in range(order[0]):
        for d in range(order[1]):
            for q in range(order[2]):
                model = ARIMA(train, order=(p, d, q))
                try:
                    model_fit = model.fit(trend='c',full_output=True,disp=1)
                    c_order = p
                    d_order = d
                    e_order = q
                    aic = model_fit.aic
                    bic = model_fit.bic
                    order_list.append(c_order)
                    order_list1.append(d_order)
                    order_list2.append(e_order)
                    aic_list.append(aic)
                    bic_list.append(bic)
                except:
                    pass
                result_df = pd.DataFrame(list(zip(order_list, order_list1, order_list2, aic_list)),columns=['p', 'd', 'q', 'AIC'])
                result_df.sort_values('AIC', inplace=True)
    return result_df

# %%
getresult_auto_arima()
# Out:
#     p  d  q         AIC
# 8   0  2  2  274.518180
# 4   0  1  1  275.985735
# 5   0  1  2  276.790308
# 11  1  1  1  277.062915
# 2   0  0  2  277.696221
# 0   0  0  0  280.653439
# 1   0  0  1  280.916018
# 13  1  2  1  281.378251
# 9   1  0  0  281.460928
# 14  2  0  0  283.118251
# 15  2  1  0  284.978814
# 10  1  1  0  285.626292
# 7   0  2  1  287.534101
# 16  2  2  0  291.543363
# 3   0  1  0  292.943622
# 17  2  2  1  294.839540
# 12  1  2  0  295.422963
# 6   0  2  0  309.650428

# %%
df = pd.read_csv('TimeSeries_small.csv')

df=df.dropna(axis=0)
df.columns = ['date', 'num']
model = ARIMA(df['num'], order=(1, 1, 0))
model_fit = model.fit()


order_list = []
order_list1 = []
order_list2 = []
aic_list = []
bic_list = []

order = [3, 3, 3]
for p in range(order[0]):
    for d in range(order[1]):
        for q in range(order[2]):
            model = ARIMA(train, order=(p, d, q))
            try:
                model_fit = model.fit(trend='c',full_output=True,disp=1)
                c_order = p
                d_order = d
                e_order = q
                aic = model_fit.aic
                bic = model_fit.bic
                order_list.append(c_order)
                order_list1.append(d_order)
                order_list2.append(e_order)
                aic_list.append(aic)
                bic_list.append(bic)
            except Exception:
                CommonLib.exception_print()

            result_df = pd.DataFrame(list(zip(order_list, order_list1, order_list2, aic_list)),
                                     columns=['p', 'd', 'q', 'AIC'])
            result_df.sort_values('AIC', inplace=True)

print(result_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-596285deb3bb> in <module>
#      17     for d in range(order[1]):
#      18         for q in range(order[2]):
# ---> 19             model = ARIMA(df, order=(p, d, q))
#      20             try:
#      21                 model_fit = model.fit(trend='c',full_output=True,disp=1)
#
# ~\conda\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#    1066         p, d, q = order
#    1067         if d == 0:  # then we just use an ARMA model
# -> 1068             return ARMA(endog, (p, q), exog, dates, freq, missing)
#    1069         else:
#    1070             mod = super(ARIMA, cls).__new__(cls)
#
# ~\conda\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#     471         import warnings
#     472         warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# --> 473         super(ARMA, self).__init__(endog, exog, dates, freq, missing=missing)
#     474         # GH 2575
#     475         array_like(endog, 'endog')
#
# ~\conda\lib\site-packages\statsmodels\tsa\base\tsa_model.py in __init__(self, endog, exog, dates, freq, missing, **kwargs)
#     409     def __init__(self, endog, exog=None, dates=None, freq=None,
#     410                  missing='none', **kwargs):
# --> 411         super(TimeSeriesModel, self).__init__(endog, exog, missing=missing,
#     412                                               **kwargs)
#     413
#
# ~\conda\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~\conda\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      75         missing = kwargs.pop('missing', 'none')
#      76         hasconst = kwargs.pop('hasconst', None)
# ---> 77         self.data = self._handle_data(endog, exog, missing, hasconst,
#      78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#
# ~\conda\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~\conda\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     670
#     671     klass = handle_data_class_factory(endog, exog)
# --> 672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     673                  **kwargs)
#
# ~\conda\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      81             self.orig_endog = endog
#      82             self.orig_exog = exog
# ---> 83             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      84
#      85         self.const_idx = None
#
# ~\conda\lib\site-packages\statsmodels\base\data.py in _convert_endog_exog(self, endog, exog)
#     506         exog = exog if exog is None else np.asarray(exog)
#     507         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 508             raise ValueError("Pandas data cast to numpy dtype of object. "
#     509                              "Check input data with np.asarray(data).")
#     510         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
