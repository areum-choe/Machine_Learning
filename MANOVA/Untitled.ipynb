# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/areum/Desktop/POC시연자료/manova1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AGE          400 non-null    int64
#  1   VITALHEIGHT  400 non-null    float64
#  2   VITALWEIGHT  400 non-null    float64
#  3   VITALP       400 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 12.6 KB

# %%
df.columns=['age','height','weight','blood']

# %%
df.head()
# Out:
#    age  height  weight  blood
# 0   49   157.0    58.0     63
# 1   45   166.0    60.0     64
# 2   54   160.0    60.0     76
# 3   56   165.0    77.0     78
# 4   54   154.0    60.0     66

# %%
df['age'].min()
# Out:
# 0

# %%
df['age'].max()
# Out:
# 83

# %%
conditionlist = [
    (df['age'] <= 30),
    (df['age'] <= 60),
    (df['age'] <= 90)]
choicelist = ['1', '2', '3']
df['age'] = np.select(conditionlist, choicelist, default='Not Specified')

# %%
df
# Out:
#     age  height  weight  blood
# 0     2   157.0    58.0     63
# 1     2   166.0    60.0     64
# 2     2   160.0    60.0     76
# 3     2   165.0    77.0     78
# 4     2   154.0    60.0     66
# ..   ..     ...     ...    ...
# 395   2   179.5    85.0     50
# 396   1   160.4    55.0     88
# 397   1   178.5    86.0     45
# 398   2   179.5    83.0     50
# 399   1   178.0    85.0     40
#
# [400 rows x 4 columns]

# %%
df.to_csv("C:/Users/areum/Desktop/POC시연자료/manova2.csv", index=False)

# %%
df=pd.read_csv('C:/Users/areum/Desktop/POC시연자료/d1f.csv')

# %%
df
# Out:
#     ACCOUNTDATE      JUPSUTIME     AMT1
# 0    2021-01-02              2    11530
# 1    2021-01-03              2    27450
# 2    2021-01-07              2    27840
# 3    2021-01-07              3    23400
# 4    2021-01-08              1  1543150
# ..          ...            ...      ...
# 744  2021-12-30  Not Specified   353590
# 745  2021-12-31              1  1483430
# 746  2021-12-31              2  5779080
# 747  2021-12-31              3  4189690
# 748  2021-12-31  Not Specified   353590
#
# [749 rows x 3 columns]

# %%
df['ACCOUNTDATE']=pd.to_datetime(df['ACCOUNTDATE'])

# %%
df=df.groupby('ACCOUNTDATE').mean()

# %%
df.reset_index()
# Out:
#     ACCOUNTDATE          AMT1
# 0    2021-01-02  1.153000e+04
# 1    2021-01-03  2.745000e+04
# 2    2021-01-07  2.562000e+04
# 3    2021-01-08  2.986420e+06
# 4    2021-01-11  2.866667e+04
# ..          ...           ...
# 244  2021-12-24  8.070000e+03
# 245  2021-12-27  2.968555e+06
# 246  2021-12-29  2.959725e+06
# 247  2021-12-30  2.955888e+06
# 248  2021-12-31  2.951448e+06
#
# [249 rows x 2 columns]

# %%
# df['JUPSUTIME']=df['JUPSUTIME'].str[0:2]
# df['JUPSUTIME']=df['JUPSUTIME'].astype(int)

# %%
# conditionlist = [
#     (df['JUPSUTIME'] <= 9),
#     (df['JUPSUTIME'] <= 14),
#     (df['JUPSUTIME'] <= 18),
#     (df['JUPSUTIME'] <= 18)]
# choicelist = ['1', '2', '3','4']
# df['JUPSUTIME'] = np.select(conditionlist, choicelist, default='Not Specified')

# %%
df['year']=df['ACCOUNTDATE'].dt.year

# %%
df
# Out:
#      JUPSUTIME     AMT1  counts
# 0            2    11530       1
# 1            2    27450       2
# 2            2    27840       2
# 3            3    23400       2
# 4            1  1543150     111
# ..         ...      ...     ...
# 589          2  5783300     393
# 590          3  4203230     280
# 591          1  1483430     107
# 592          2  5779080     393
# 593          3  4189690     279
#
# [594 rows x 3 columns]

# %%
df=df[df['year']==2021]

# %%
df.reset_index(drop=True)
# Out:
#        ACCOUNTDATE   AMT1 JUPSUTIME  year
# 0       2021-09-06  15640         2  2021
# 1       2021-01-08  15350         3  2021
# 2       2021-01-03  15920         2  2021
# 3       2021-01-03  11530         2  2021
# 4       2021-01-02  11530         2  2021
# ...            ...    ...       ...   ...
# 122217  2021-11-26  15640         2  2021
# 122218  2021-11-26  15350         3  2021
# 122219  2021-11-26  15350         1  2021
# 122220  2021-11-26  15640         1  2021
# 122221  2021-11-26  15640         2  2021
#
# [122222 rows x 4 columns]

# %%
df=df[['ACCOUNTDATE','AMT1','JUPSUTIME']]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#        ACCOUNTDATE   AMT1 JUPSUTIME
# 0       2021-09-06  15640         2
# 1       2021-01-08  15350         3
# 2       2021-01-03  15920         2
# 3       2021-01-03  11530         2
# 4       2021-01-02  11530         2
# ...            ...    ...       ...
# 122217  2021-11-26  15640         2
# 122218  2021-11-26  15350         3
# 122219  2021-11-26  15350         1
# 122220  2021-11-26  15640         1
# 122221  2021-11-26  15640         2
#
# [122222 rows x 3 columns]

# %%
df.head(10)
# Out:
#   ACCOUNTDATE   AMT1 JUPSUTIME
# 0  2021-09-06  15640         2
# 1  2021-01-08  15350         3
# 2  2021-01-03  15920         2
# 3  2021-01-03  11530         2
# 4  2021-01-02  11530         2
# 5  2021-01-07  11700         3
# 6  2021-01-07  16140         2
# 7  2021-01-07  11700         3
# 8  2021-01-08  15640         1
# 9  2021-01-08  15920         3

# %%
df = df.sort_values(by='ACCOUNTDATE' ,ascending=False)

# %%
group=df.groupby(["ACCOUNTDATE",'JUPSUTIME'])
print(group.size().reset_index(name='counts'))
# Out:
#     ACCOUNTDATE      JUPSUTIME  counts
# 0    2021-01-02              2       1
# 1    2021-01-03              2       2
# 2    2021-01-07              2       2
# 3    2021-01-07              3       2
# 4    2021-01-08              1     111
# ..          ...            ...     ...
# 744  2021-12-30  Not Specified      20
# 745  2021-12-31              1     107
# 746  2021-12-31              2     393
# 747  2021-12-31              3     279
# 748  2021-12-31  Not Specified      20
#
# [749 rows x 3 columns]

# %%
d1f=df.groupby(by=['ACCOUNTDATE', 'JUPSUTIME'], as_index=False).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-915ae5d951ac> in <module>
# ----> 1 d1f=df.groupby(by=['ACCOUNTDATE', 'JUPSUTIME'], as_index=False).sum()
#
# ~\conda\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\conda\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
# ...

# %%
d1f
# Out:
#     ACCOUNTDATE      JUPSUTIME     AMT1
# 0    2021-01-02              2    11530
# 1    2021-01-03              2    27450
# 2    2021-01-07              2    27840
# 3    2021-01-07              3    23400
# 4    2021-01-08              1  1543150
# ..          ...            ...      ...
# 744  2021-12-30  Not Specified   353590
# 745  2021-12-31              1  1483430
# 746  2021-12-31              2  5779080
# 747  2021-12-31              3  4189690
# 748  2021-12-31  Not Specified   353590
#
# [749 rows x 3 columns]

# %%
group=df.groupby(["ACCOUNTDATE",'JUPSUTIME'])
df=group.size().reset_index(name='counts')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-196-59130468c0ed> in <module>
# ----> 1 group=df.groupby(["ACCOUNTDATE",'JUPSUTIME'])
#       2 df=group.size().reset_index(name='counts')
#
# ~\conda\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\conda\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
# ...

# %%
df=df[['ACCOUNTDATE','counts']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-197-a9276b4a004a> in <module>
# ----> 1 df=df[['ACCOUNTDATE','counts']]
#
# ~\conda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\conda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ...

# %%
df['ACCOUNTDATE'].dt.weekday
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\conda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ACCOUNTDATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-198-c2f19bb96c92> in <module>
# ----> 1 df['ACCOUNTDATE'].dt.weekday
# ...

# %%
df.to_csv("C:/Users/areum/Desktop/POC시연자료/2.csv", index=False)

# %%
df.to_csv("C:/Users/areum/Desktop/POC시연자료/manova방문시간대 환자수금액.csv", index=False)

# %%
df=pd.read_csv('C:/Users/areum/Desktop/POC시연자료/manova방문시간대 그룹지어 놓고 환자수금액.csv')

# %%
df
# Out:
#      JUPSUTIME     AMT1  counts
# 0            2    11530       1
# 1            2    27450       2
# 2            2    27840       2
# 3            3    23400       2
# 4            1  1543150     111
# ..         ...      ...     ...
# 589          2  5783300     393
# 590          3  4203230     280
# 591          1  1483430     107
# 592          2  5779080     393
# 593          3  4189690     279
#
# [594 rows x 3 columns]

# %%
df=pd.read_csv('C:/Users/areum/Desktop/POC시연자료/manova요일별 일반 환자 수, 매출액.csv')

# %%
df['ACCOUNTDATE']=pd.to_datetime(df['ACCOUNTDATE'])

# %%
df=df.groupby(by=['ACCOUNTDATE'], as_index=False).sum()

# %%
df
# Out:
#     ACCOUNTDATE  counts      AMT1
# 0    2021-01-02       1     11530
# 1    2021-01-03       2     27450
# 2    2021-01-07       4     51240
# 3    2021-01-08     808  11945680
# 4    2021-01-11       6     86000
# ..          ...     ...       ...
# 244  2021-12-24       1      8070
# 245  2021-12-27     804  11874220
# 246  2021-12-29     801  11838900
# 247  2021-12-30     800  11823550
# 248  2021-12-31     799  11805790
#
# [249 rows x 3 columns]

# %%
df['sdf']=df['ACCOUNTDATE'].dt.weekday

# %%
df
# Out:
#     ACCOUNTDATE  counts      AMT1  sdf
# 0    2021-01-02       1     11530    5
# 1    2021-01-03       2     27450    6
# 2    2021-01-07       4     51240    3
# 3    2021-01-08     808  11945680    4
# 4    2021-01-11       6     86000    0
# ..          ...     ...       ...  ...
# 244  2021-12-24       1      8070    4
# 245  2021-12-27     804  11874220    0
# 246  2021-12-29     801  11838900    2
# 247  2021-12-30     800  11823550    3
# 248  2021-12-31     799  11805790    4
#
# [249 rows x 4 columns]
