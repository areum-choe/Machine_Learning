# %%
import pandas as pd

df = pd.read_csv('C:/Users/chlal/Desktop/POC시연자료/상관분석_혈압나이성별온도.csv')

# %%
df['sex'] = df['sex'].map({'F':0, 'M':1})

# %%
df=df.dropna(axis=0)

# %%
df['height']=df['height'].astype(int)
df['weight']=df['weight'].astype(int)
df['temperature']=df['temperature'].astype(int)
df['pulse']=df['pulse'].astype(int)

# %% [markdown]
# # 데이터 세트 분리하기 (Training & Test)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x = df[['age', 'sex', 'weight', 'diastolic', 'systolic', 'temperature', 'pulse']]
y = df[['height']]

# %%
x_train, x_test,y_train, y_test =train_test_split(x,y,train_size = 0.7,
                                                  test_size = 0.3)

# %%
linear = LinearRegression()
linear.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
my_apartment = [[25,1, 80, 77,130,36,90]]
my_predict = linear.predict(my_apartment)
my_predict
# Out:
# array([[174.85832168]])

# %%
y_predict = linear.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual Height")
plt.ylabel("Predicted Height")
plt.title("MULTIPLE REGRESSION")
plt.show()

# %%
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# %%
a=sm.ols(formula = 'height ~ age + sex + weight + diastolic + systolic + temperature + pulse ', data=df).fit()
a.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.423
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     232.6
# Date:                Thu, 23 Dec 2021   Prob (F-statistic):          7.57e-260
# Time:                        09:16:21   Log-Likelihood:                -7954.6
# No. Observations:                2231   AIC:                         1.593e+04
# Df Residuals:                    2223   BIC:                         1.597e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     161.2870      6.159     26.187      0.000     149.209     173.365
# age            -0.1517      0.012    -13.101      0.000      -0.174      -0.129
# sex            11.9950      0.404     29.686      0.000      11.203      12.787
# weight          0.0766      0.012      6.387      0.000       0.053       0.100
# diastolic      -0.0021      0.008     -0.266      0.791      -0.018       0.014
# systolic        0.0041      0.011      0.363      0.717      -0.018       0.026
# temperature    -0.0265      0.165     -0.160      0.873      -0.351       0.298
# pulse          -0.0094      0.009     -0.999      0.318      -0.028       0.009
# ==============================================================================
# Omnibus:                     1625.193   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3208262.530
# Skew:                           1.887   Prob(JB):                         0.00
# Kurtosis:                     188.738   Cond. No.                     6.73e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.73e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
summary_arr = [str(a.summary())]
df_summary = pd.DataFrame(summary_arr)
df_summary.rename(columns={df_summary.columns[0]: "SUMMARY"}, inplace=True)

# %%
corr_df = df.corr()
corr_df = corr_df.apply(lambda x: round(x, 2))
corr_df_unstack = corr_df.unstack()

# %%
corr_df
# Out:
#               age   sex  height  weight  diastolic  systolic  temperature  \
# age          1.00 -0.07   -0.27   -0.14      -0.01      0.11        -0.04
# sex         -0.07  1.00    0.60    0.42       0.07      0.23        -0.07
# height      -0.27  0.60    1.00    0.37       0.05      0.13        -0.03
# weight      -0.14  0.42    0.37    1.00       0.12      0.29        -0.02
# diastolic   -0.01  0.07    0.05    0.12       1.00      0.39        -0.00
# systolic     0.11  0.23    0.13    0.29       0.39      1.00         0.01
# temperature -0.04 -0.07   -0.03   -0.02      -0.00      0.01         1.00
# pulse       -0.15 -0.02    0.01    0.01       0.07      0.11         0.07
#
#              pulse
# age          -0.15
# sex          -0.02
# height        0.01
# weight        0.01
# diastolic     0.07
# systolic      0.11
# temperature   0.07
# pulse         1.00

# %%
all = pd.DataFrame(corr_df_unstack[corr_df_unstack <= 1].sort_values(ascending=False), columns=['corr'])

# %%
all
# Out:
#                          corr
# pulse       pulse        1.00
# temperature temperature  1.00
# sex         sex          1.00
# height      height       1.00
# weight      weight       1.00
# ...                       ...
# age         weight      -0.14
#             pulse       -0.15
# pulse       age         -0.15
# age         height      -0.27
# height      age         -0.27
#
# [64 rows x 1 columns]

# %%
all=all.reset_index()

# %%
col_name1 = 'x'
col_name2 = 'y'
col_name3 = 'corr'
all.columns=[col_name1, col_name2, col_name3]

# %%
all
# Out:
#               x            y  corr
# 0         pulse        pulse  1.00
# 1   temperature  temperature  1.00
# 2           sex          sex  1.00
# 3        height       height  1.00
# 4        weight       weight  1.00
# ..          ...          ...   ...
# 59          age       weight -0.14
# 60          age        pulse -0.15
# 61        pulse          age -0.15
# 62          age       height -0.27
# 63       height          age -0.27
#
# [64 rows x 3 columns]

# %%
records = []
records.append(all)

# %%
df_summary
# Out:
#                                              SUMMARY
# 0                              OLS Regression Res...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x_data2 = df[['age', 'sex', 'weight', 'diastolic', 'systolic', 'temperature', 'pulse']]

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x_data2.values, i) for i in range(x_data2.shape[1])]
vif["features"] = x_data2.columns
vif
# Out:
#    VIF Factor     features
# 0   10.599824          age
# 1    2.510653          sex
# 2   20.108059       weight
# 3   13.698621    diastolic
# 4   66.540973     systolic
# 5   73.807495  temperature
# 6   19.867372        pulse

# %%
result_all=pd.concat([df_summary,vif],axis=1)

# %%
result_all
# Out:
#                                              SUMMARY  VIF Factor     features
# 0                              OLS Regression Res...   10.599824          age
# 1                                                NaN    2.510653          sex
# 2                                                NaN   20.108059       weight
# 3                                                NaN   13.698621    diastolic
# 4                                                NaN   66.540973     systolic
# 5                                                NaN   73.807495  temperature
# 6                                                NaN   19.867372        pulse
